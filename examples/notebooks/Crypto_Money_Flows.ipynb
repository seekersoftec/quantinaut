# %% [markdown]
# # BTC Dominance
#
# Try to predict the dominance chart - future dominance values
#
# lower might mean money would most likely be pulled from BTC.
#
# higher might mean money would most likely be injected into BTC.
#
# # https://coinmarketcap.com/charts/bitcoin-dominance/
